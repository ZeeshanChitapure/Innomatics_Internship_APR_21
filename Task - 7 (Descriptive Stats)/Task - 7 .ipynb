# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("D:\DOWNLOADS/data(1).csv")
df.head()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# 1             79920               Illiterate                      1
# 2            112800           Under-Graduate                      1
# 3             97200               Illiterate                      1
# 4            147000                 Graduate                      1

# %%
df.isna().sum()
# Out:
# Mthly_HH_Income             0
# Mthly_HH_Expense            0
# No_of_Fly_Members           0
# Emi_or_Rent_Amt             0
# Annual_HH_Income            0
# Highest_Qualified_Member    0
# No_of_Earning_Members       0
# dtype: int64

# %% [markdown]
# # Mean

# %% [markdown]
# Mean is the average value of given numbers.

# %% [markdown]
# Mean=sum of all observations /total number of observation

# %%
df.mean()
# Out:
# Mthly_HH_Income           41558.00
# Mthly_HH_Expense          18818.00
# No_of_Fly_Members             4.06
# Emi_or_Rent_Amt            3060.00
# Annual_HH_Income         490019.04
# No_of_Earning_Members         1.46
# dtype: float64

# %%
df["Mthly_HH_Income"].mean() #single column mean od dataframe
# Out:
# 41558.0

# %% [markdown]
# # Median

# %% [markdown]
# Median is the "middle" of sorted list of numbers

# %% [markdown]
# 5,18 and 11
# put them in order
# 5,11,18
# the middle is 11 so median is 11.
#
# for even list:
# 1,2,4,7

# %% [markdown]
# 2+4=6/2=3

# %% [markdown]
# so, 3 is the median.

# %%
df.median()
# Out:
# Mthly_HH_Income           35000.0
# Mthly_HH_Expense          15500.0
# No_of_Fly_Members             4.0
# Emi_or_Rent_Amt               0.0
# Annual_HH_Income         447420.0
# No_of_Earning_Members         1.0
# dtype: float64

# %%
df["Mthly_HH_Income"].median()
# Out:
# 35000.0

# %% [markdown]
# # Mode

# %% [markdown]
# The mode is the value that appears most frequent in a data set

# %% [markdown]
# A set of data may have one or more mode or no mode

# %% [markdown]
# 1,9,8,6,5,9,12,15,9,18,45,9

# %% [markdown]
# Arrange the in order

# %% [markdown]
# 1,5,6,8,9,9,9,9,12,15,18,45

# %% [markdown]
# Here mode is 9

# %%
df["Mthly_HH_Income"].mode()
# Out:
# 0    45000
# dtype: int64

# %% [markdown]
# # Variance

# %% [markdown]
# The average of the squared differences from Mean

# %% [markdown]
# Mean=(1+2+3+4+5)/5=3
# To calculate Variance, take each difference, square it, and then average the result.
# 3-1=2=2^2=4
# 3-2=1^2=1
# 3-3=0^2=0
# 3-4=-1^2=1
# 3-5=-2^2=4
# $$
# variance=\sigma^2=(4+1+0+1+4)/5=2
# $$
# variance is 2

# %% [markdown]
# # Standard Deviation

# %% [markdown]
# Standard devaition is square root of variance.
# It is a measure of the amount variation or dispersion of a set of values.

# %% [markdown]
# $$ 𝜎=\sqrt variance\$$

# %% [markdown]
# $$ 𝜎=\sqrt2=1.41421 $$

# %%
df.std()
# Out:
# Mthly_HH_Income           26097.908979
# Mthly_HH_Expense          12090.216824
# No_of_Fly_Members             1.517382
# Emi_or_Rent_Amt            6241.434948
# Annual_HH_Income         320135.792123
# No_of_Earning_Members         0.734291
# dtype: float64

# %%
df["Mthly_HH_Income"].std()
# Out:
# 26097.908978713687

# %% [markdown]
# # Correlation

# %% [markdown]
# It is used to get relationship between two quantitative variables or categorical variables.

# %%
corr=df.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 1 represents perfectly correlated.

# %% [markdown]
# # Normal Distribution

# %% [markdown]
# Normal Distribution, also known as Gaussian distribution, is ubiquitous in Data Science. You will encounter it at many places especially in topics of statistical inference. It is one of the assumptions of many data science algorithms too.

# %% [markdown]
# ![](normal_dist.png)

# %% [markdown]
# ### Feature of Normal Distribution

# %% [markdown]
# A normal distribution has a bell-shaped density curve described by its mean μ and standard deviation σ. The density curve is symmetrical, centered about its mean, with its spread determined by its standard deviation showing that data near the mean are more frequent in occurrence than data far from the mean.

# %%
from scipy.stats import norm
data_normal = norm.rvs(size=10000,loc=0,scale=1)
ax = sns.histplot(data_normal,
                  kde=True,
                  color='skyblue')
ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# [Text(0.5, 0, 'Normal Distribution'), Text(0, 0.5, 'Frequency')]

# %%
plt.style.use('ggplot')
df.hist(figsize=(16,10))
# Out:
# array([[<AxesSubplot:title={'center':'Mthly_HH_Income'}>,
#         <AxesSubplot:title={'center':'Mthly_HH_Expense'}>],
#        [<AxesSubplot:title={'center':'No_of_Fly_Members'}>,
#         <AxesSubplot:title={'center':'Emi_or_Rent_Amt'}>],
#        [<AxesSubplot:title={'center':'Annual_HH_Income'}>,
#         <AxesSubplot:title={'center':'No_of_Earning_Members'}>]],
#       dtype=object)

# %% [markdown]
# # Positively Skewed & Negatively Skewed Normal Distribution

# %% [markdown]
# Skewness is the measure of symmetry or asymmetry of data distribution.
# A distribution or data set is said to be symmetric if it looks the same to the left and right points of center.
# if data is skewed towards rightside it is Postively skewed.
# if data is skewed towards leftside it is Negatively skewed.

# %%
df.skew()
# Out:
# Mthly_HH_Income          0.924615
# Mthly_HH_Expense         1.199461
# No_of_Fly_Members        0.113674
# Emi_or_Rent_Amt          3.403680
# Annual_HH_Income         1.192949
# No_of_Earning_Members    1.593301
# dtype: float64

# %%
sns.histplot(x="Mthly_HH_Income", data=df) #histogram shows how data is distributed 
plt.show()

# %% [markdown]
# If skewness is less than -1 or greater than 1, the distribution is highly skewed.
# If skewness is between -1 and -0.5 or between 0.5 and 1, the distribution is moderately skewed.
# If skewness is between -0.5 and 0.5, the distribution is approximately symmetric.

# %% [markdown]
# # Effect on Mean, Median and Mode due to Skewness

# %% [markdown]
# If the distribution of data is Skewed to the left, the mean is less than the median, which is often less than the mode.
#
# If the distribution of data is Skewed to the right, the mode is often less than the median, which is less than the mean.

# %% [markdown]
# ![](skewness.jpg)

# %% [markdown]
# # QQ Plot

# %% [markdown]
# This is a visual or graphical test to check for normality of the data. This test helps us identify outliers and skewness. The test is performed by plotting the data verses theoretical quartiles. The same data is also plotted on a histogram to confirm normality.
#
# Any deviation from the straight line in normal plot or skewness/multi-modality in histogram shows that the data does not pass the normality test.
#
# Now, I will plot the Q-Q Plot as follows:-

# %%
import pylab 
import scipy.stats as stats


for var in ['Mthly_HH_Income', 'Mthly_HH_Expense', 'No_of_Fly_Members', 'Emi_or_Rent_Amt', 'Annual_HH_Income', 'No_of_Earning_Members']:
    
    plt.figure(figsize=(15,6))
    plt.subplot(1, 2, 2)
    stats.probplot(df[var], dist="norm", plot=pylab)
    plt.title('Q-Q plot of '+ var)

    plt.show()

# %% [markdown]
# # Box Cox

# %%
pareto_plot= np.random.pareto(a = 150, size = 1000)
sns.distplot(pareto_plot)
# Out:
# C:\Users\czees\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# A Box Cox transformation is defined as way to transform non-normal dependent variables in our data to a normal shape through which we can run a lot more rest than we could have.

# %%
fitted_normplot, fitted_lambda = stats.boxcox(pareto_plot)

# %%
sns.distplot(fitted_normplot)
# Out:
# C:\Users\czees\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# We can see that the non-normal distribution was converted into a normal distribution or rather close to normal using the SciPy.stats.boxcox().
